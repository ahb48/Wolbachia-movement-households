# %%
# %matplotlib inline
import numpy as np
import pylab as plt
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the CSV file into a DataFrame
ratios_df = pd.read_csv('wild_free_all_hholds_rel.csv')

# Convert the DataFrame to a dictionary for easier access
ratios_dict = {(eval(row['SexRatio']), row['ReleaseTimeStep']): row['InvProb'] for _, row in ratios_df.iterrows()}
ratios_dict
# Out:
# {((3, 3), 300): 1.0,
#  ((5, 1), 250): 1.0,
#  ((5, 10), 200): 1.0,
#  ((5, 5), 350): 1.0,
#  ((5, 10), 250): 1.0,
#  ((5, 5), 150): 1.0,
#  ((10, 1), 350): 1.0,
#  ((10, 1), 150): 1.0,
#  ((1, 1), 300): 0.9133,
#  ((10, 10), 350): 1.0,
#  ((5, 3), 300): 1.0,
#  ((10, 10), 150): 1.0,
#  ((3, 1), 300): 1.0,
#  ((10, 5), 300): 1.0,
#  ((3, 10), 300): 1.0,
#  ((3, 5), 200): 1.0,
#  ((10, 3), 200): 1.0,
#  ((3, 5), 250): 1.0,
#  ((10, 3), 250): 1.0,
#  ((3, 3), 350): 1.0,
#  ((5, 1), 300): 1.0,
#  ((3, 3), 150): 1.0,
#  ((5, 10), 300): 1.0,
#  ((5, 5), 200): 1.0,
#  ((5, 5), 250): 1.0,
#  ((1, 1), 350): 0.8256000000000001,
#  ((10, 1), 200): 1.0,
#  ((5, 3), 350): 1.0,
#  ((1, 1), 150): 1.0,
#  ((10, 1), 250): 1.0,
#  ((10, 10), 200): 1.0,
#  ((5, 3), 150): 1.0,
#  ((3, 1), 350): 1.0,
#  ((10, 5), 350): 1.0,
#  ((10, 10), 250): 1.0,
#  ((3, 1), 150): 1.0,
#  ((10, 5), 150): 1.0,
#  ((3, 10), 350): 1.0,
#  ((3, 10), 150): 1.0,
#  ((3, 5), 300): 1.0,
#  ((10, 3), 300): 1.0,
# ...

# %%
# Load the CSV file into a DataFrame
ratios_single_df = pd.read_csv('wild_free_propn_hhold_50_norel.csv')

# Convert the DataFrame to a dictionary for easier access
ratios_dict = {(eval(row['SexRatio']), row['ReleaseTimeStep']): row['InvProb'] for _, row in ratios_single_df.iterrows()}
ratios_dict
# Out:
# {((3, 3), 300): 1.0,
#  ((5, 1), 250): 1.0,
#  ((5, 10), 200): 1.0,
#  ((5, 5), 350): 1.0,
#  ((5, 10), 250): 1.0,
#  ((5, 5), 150): 1.0,
#  ((10, 1), 350): 1.0,
#  ((10, 1), 150): 1.0,
#  ((1, 1), 300): 0.1843999999999999,
#  ((10, 10), 350): 1.0,
#  ((5, 3), 300): 1.0,
#  ((10, 10), 150): 1.0,
#  ((3, 1), 300): 1.0,
#  ((10, 5), 300): 1.0,
#  ((3, 10), 300): 1.0,
#  ((3, 5), 200): 1.0,
#  ((10, 3), 200): 1.0,
#  ((3, 5), 250): 1.0,
#  ((10, 3), 250): 1.0,
#  ((3, 3), 350): 1.0,
#  ((5, 1), 300): 1.0,
#  ((3, 3), 150): 1.0,
#  ((5, 10), 300): 1.0,
#  ((5, 5), 200): 1.0,
#  ((5, 5), 250): 1.0,
#  ((1, 1), 350): 0.1329999999999999,
#  ((10, 1), 200): 1.0,
#  ((5, 3), 350): 1.0,
#  ((1, 1), 150): 0.6568,
#  ((10, 1), 250): 1.0,
#  ((10, 10), 200): 1.0,
#  ((5, 3), 150): 1.0,
#  ((3, 1), 350): 0.9998,
#  ((10, 5), 350): 1.0,
#  ((10, 10), 250): 1.0,
#  ((3, 1), 150): 1.0,
#  ((10, 5), 150): 1.0,
#  ((3, 10), 350): 1.0,
#  ((3, 10), 150): 1.0,
#  ((3, 5), 300): 1.0,
# ...

# %%
# Load the CSV file into a DataFrame
wolb_pers_single_df = pd.read_csv('wolb_pers_all_hholds.csv')

# Convert the DataFrame to a dictionary for easier access
ratios_dict = {(eval(row['SexRatio']), row['ReleaseTimeStep']): row['PersTime'] for _, row in wolb_pers_single_df.iterrows()}
ratios_dict
# Out:
# {((3, 3), 300): 183.49,
#  ((5, 1), 250): 442.08,
#  ((5, 10), 200): 624.81,
#  ((5, 5), 350): 521.32,
#  ((5, 10), 250): 626.4,
#  ((5, 5), 150): 545.16,
#  ((10, 1), 350): 648.9,
#  ((10, 1), 150): 650.95,
#  ((1, 1), 300): 13.13,
#  ((10, 10), 350): 697.98,
#  ((5, 3), 300): 520.29,
#  ((10, 10), 150): 752.53,
#  ((3, 1), 300): 172.55,
#  ((10, 5), 300): 629.23,
#  ((3, 10), 300): 376.93,
#  ((3, 5), 200): 342.46,
#  ((10, 3), 200): 700.55,
#  ((3, 5), 250): 219.36,
#  ((10, 3), 250): 705.92,
#  ((3, 3), 350): 193.78,
#  ((5, 1), 300): 499.36,
#  ((3, 3), 150): 243.97,
#  ((5, 10), 300): 586.54,
#  ((5, 5), 200): 543.18,
#  ((5, 5), 250): 541.77,
#  ((1, 1), 350): 12.99,
#  ((10, 1), 200): 627.53,
#  ((5, 3), 350): 480.92,
#  ((1, 1), 150): 12.5,
#  ((10, 1), 250): 669.13,
#  ((10, 10), 200): 703.0,
#  ((5, 3), 150): 509.23,
#  ((3, 1), 350): 137.0,
#  ((10, 5), 350): 649.37,
#  ((10, 10), 250): 693.71,
#  ((3, 1), 150): 226.14,
#  ((10, 5), 150): 696.1,
# ...

# %%
# Load the CSV file into a DataFrame
wolb_av_single_df = pd.read_csv('wolb_av_hhold_all_rel.csv')

# Convert the DataFrame to a dictionary for easier access
ratios_dict = {(eval(row['SexRatio']), row['ReleaseTimeStep']): row['WolbAv'] for _, row in wolb_av_single_df.iterrows()}
ratios_dict
# Out:
# {((3, 3), 300): 9.774600000000005,
#  ((5, 1), 250): 10.421,
#  ((5, 10), 200): 11.487800000000002,
#  ((5, 5), 350): 10.102899999999998,
#  ((5, 10), 250): 10.4304,
#  ((5, 5), 150): 10.4869,
#  ((10, 1), 350): 10.1191,
#  ((10, 1), 150): 10.620699999999998,
#  ((1, 1), 300): 6.7501,
#  ((10, 10), 350): 10.015300000000003,
#  ((5, 3), 300): 9.836899999999998,
#  ((10, 10), 150): 10.566500000000003,
#  ((3, 1), 300): 9.407499999999995,
#  ((10, 5), 300): 9.911700000000002,
#  ((3, 10), 300): 9.961899999999998,
#  ((3, 5), 200): 11.018300000000002,
#  ((10, 3), 200): 12.111399999999996,
#  ((3, 5), 250): 10.325000000000005,
#  ((10, 3), 250): 10.4681,
#  ((3, 3), 350): 10.027999999999995,
#  ((5, 1), 300): 9.929300000000003,
#  ((3, 3), 150): 10.281800000000002,
#  ((5, 10), 300): 9.8802,
#  ((5, 5), 200): 11.521300000000002,
#  ((5, 5), 250): 10.332800000000002,
#  ((1, 1), 350): 4.865900000000002,
#  ((10, 1), 200): 11.965799999999994,
#  ((5, 3), 350): 10.0304,
# ...

# %%
# Load the CSV file into a DataFrame
wolb_av_df = pd.read_csv('wolb_av_hhold_50_norel.csv')

# Convert the DataFrame to a dictionary for easier access
ratios_dict = {(eval(row['SexRatio']), row['ReleaseTimeStep']): row['WolbAv'] for _, row in wolb_av_df.iterrows()}
ratios_dict
# Out:
# {((3, 3), 300): 7.662599999999998,
#  ((5, 1), 250): 9.5508,
#  ((5, 10), 200): 10.6728,
#  ((5, 5), 350): 9.283599999999998,
#  ((5, 10), 250): 10.0202,
#  ((5, 5), 150): 10.0582,
#  ((10, 1), 350): 10.0692,
#  ((10, 1), 150): 10.2666,
#  ((1, 1), 300): 1.3702,
#  ((10, 10), 350): 10.141000000000002,
#  ((5, 3), 300): 8.554399999999998,
#  ((10, 10), 150): 10.471799999999998,
#  ((3, 1), 300): 6.7784,
#  ((10, 5), 300): 9.913799999999998,
#  ((3, 10), 300): 7.348999999999997,
#  ((3, 5), 200): 9.7,
#  ((10, 3), 200): 11.312400000000004,
#  ((3, 5), 250): 7.9642,
#  ((10, 3), 250): 10.528600000000004,
#  ((3, 3), 350): 7.080400000000002,
#  ((5, 1), 300): 8.485200000000003,
#  ((3, 3), 150): 10.1088,
#  ((5, 10), 300): 9.4986,
#  ((5, 5), 200): 10.6552,
#  ((5, 5), 250): 9.6878,
#  ((1, 1), 350): 1.1529999999999994,
#  ((10, 1), 200): 11.2252,
#  ((5, 3), 350): 9.0128,
#  ((1, 1), 150): 5.979400000000002,
#  ((10, 1), 250): 10.4728,
#  ((10, 10), 200): 11.476000000000004,
# ...

# %%
plt.figure(figsize=(7, 4))

bar_labels = [(1,1), (3,1), (3,3), (3,5), (3,10), (5,1), (5,3), (5,5), (5,10), (10,3), (10,5), (10,10), (10,1)]#[(1,1), (3,1), (3,3), (3,5), (3,10), (5,1), (5,3), (5,5), (5,10), (10,1), (10,3), (10,5), (10,10)]
width = 0.2

heights_10 = [
    ratios_dict[((1, 1), 150)],
    ratios_dict[((3, 1), 150)],
    ratios_dict[((3, 3), 150)],
    ratios_dict[((3, 5), 150)],
    ratios_dict[((3, 10), 150)],
    ratios_dict[((5, 1), 150)],
    ratios_dict[((5, 3), 150)],
    ratios_dict[((5, 5), 150)],
    ratios_dict[((5, 10), 150)],
    ratios_dict[((10, 1), 150)],
    ratios_dict[((10, 3), 150)],
    ratios_dict[((10, 5), 150)],
    ratios_dict[((10, 10), 150)]
]

heights_25 = [
    ratios_dict[((1, 1), 200)],
    ratios_dict[((3, 1), 200)],
    ratios_dict[((3, 3), 200)],
    ratios_dict[((3, 5), 200)],
    ratios_dict[((3, 10), 200)],
    ratios_dict[((5, 1), 200)],
    ratios_dict[((5, 3), 200)],
    ratios_dict[((5, 5), 200)],
    ratios_dict[((5, 10), 200)],
    ratios_dict[((10, 1), 200)],
    ratios_dict[((10, 3), 200)],
    ratios_dict[((10, 5), 200)],
    ratios_dict[((10, 10), 200)]
]

heights_50 = [
    ratios_dict[((1, 1), 250)],
    ratios_dict[((3, 1), 250)],
    ratios_dict[((3, 3), 250)],
    ratios_dict[((3, 5), 250)],
    ratios_dict[((3, 10), 250)],
    ratios_dict[((5, 1), 250)],
    ratios_dict[((5, 3), 250)],
    ratios_dict[((5, 5), 250)],
    ratios_dict[((5, 10), 250)],
    ratios_dict[((10, 1), 250)],
    ratios_dict[((10, 3), 250)],
    ratios_dict[((10, 5), 250)],
    ratios_dict[((10, 10), 250)]
]

heights_75 = [
    ratios_dict[((1, 1), 300)],
    ratios_dict[((3, 1), 300)],
    ratios_dict[((3, 3), 300)],
    ratios_dict[((3, 5), 300)],
    ratios_dict[((3, 10), 300)],
    ratios_dict[((5, 1), 300)],
    ratios_dict[((5, 3), 300)],
    ratios_dict[((5, 5), 300)],
    ratios_dict[((5, 10), 300)],
    ratios_dict[((10, 1), 300)],
    ratios_dict[((10, 3), 300)],
    ratios_dict[((10, 5), 300)],
    ratios_dict[((10, 10), 300)]    
]

heights_100 = [
    ratios_dict[((1, 1), 350)],
    ratios_dict[((3, 1), 350)],
    ratios_dict[((3, 3), 350)],
    ratios_dict[((3, 5), 350)],
    ratios_dict[((3, 10), 350)],
    ratios_dict[((5, 1), 350)],
    ratios_dict[((5, 3), 350)],
    ratios_dict[((5, 5), 350)],
    ratios_dict[((5, 10), 350)],
    ratios_dict[((10, 1), 350)],
    ratios_dict[((10, 3), 350)],
    ratios_dict[((10, 5), 350)],
    ratios_dict[((10, 10), 350)]    
]

positions = np.arange(len(bar_labels))
colors = ['C0', 'C1', 'C2', 'C3', 'C4']

positions_100 = positions - 2*width
positions_75 = positions - width
positions_50 = positions
positions_25 = positions + width
positions_10 = positions + 2*width

plt.style.use('ggplot')

# Plot bars side by side
plt.bar(positions_10, heights_10, width=width, color=colors[0], label=r'$\delta t = 150$')
plt.bar(positions_25, heights_25, width=width, color=colors[1], label=r'$\delta t = 200$')
plt.bar(positions_50, heights_50, width=width, color=colors[2], label=r'$\delta t = 250$')
plt.bar(positions_75, heights_75, width=width, color=colors[3], label=r'$\delta t = 300$')
plt.bar(positions_100, heights_100, width=width, color=colors[4], label=r'$\delta t = 350$')

# Set labels and title with font size 15
plt.xlabel('Sex Ratio (no. female, no. male)', color='black', fontsize=15)
plt.ylabel('Wolbachia Persistence time \n (days)', color='black', fontsize=15)
plt.title('Releasing households (100%)', color='black', fontsize=15)

# Set tick labels with font size 15
plt.xticks(positions, labels=bar_labels, color='black', rotation=45, fontsize=15)
plt.yticks(color='black', fontsize=15)

# Set legend with font size 15
plt.legend(fontsize=13, loc='lower right')

# Save and show the plot
plt.savefig('wolbachia_pers_time_100rel.pdf', bbox_inches='tight')
plt.show()
